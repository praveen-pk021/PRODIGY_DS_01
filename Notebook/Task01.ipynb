# %% [markdown]
# # 🌍 Global Population Distribution Analysis
#
# ## Prodigy InfoTech Data Science Internship
#
# ### Task 01: Population Distribution Visualization
#
# **Author:** K. Praveen Kumar
#
# **Goal:** Analyze the distribution of world population data across countries and continents using Python and present the findings in a professional, visually appealing way.
#
# > Note: The dataset contains country-level population totals, not age-group or gender-based information. The analysis therefore focuses on the distribution of population across countries and continents.
#
# ---

# %% [markdown]
# ## 🎯 Objective
#
# The objective of this project is to analyze and visualize the distribution of the world's population using Python. By creating histograms and bar charts, we can better understand how population varies across countries and identify trends and patterns in the data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Improve plot appearance
plt.style.use("ggplot")

# Display plots inside notebook
# %matplotlib inline

# %%
df = pd.read_csv("../Dataset/world_population.csv")

df.head()
